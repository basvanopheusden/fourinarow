# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rcParams,font_manager
rcParams['font.sans-serif'] = "Helvetica Neue LT Std"
rcParams['font.family'] = "sans-serif"
rcParams['font.weight'] = "roman"
rcParams['font.style'] = "normal"

fig_direc = 'C:/Users/Bas/Google Drive/Bas Zahy Gianni - Games/Manuscripts/Paper/Figures/'

# %%
x=np.linspace(0,20,1000)

#  switch(cond){
#    default: wait_time=h.iterations==0?2500:a; break; //no limit
#    case 1: wait_time=h.iterations==0?2500:(4000-log(1.0+exp((4000.0-a)/1000.0))*1000.0); break; // 5 seconds
#    case 2: wait_time=h.iterations==0?2500:(8000-log(1.0+exp((8000.0-1.2*a)/2000.0))*2000.0); break; // 10 seconds
#    case 3: wait_time=h.iterations==0?2500:(16000-log(1.0+exp((16000.0-1.5*a)/4000.0))*4000.0); break; // 20 seconds
#  }
fig,ax = plt.subplots()
ax.plot(x,4-np.log(1+np.exp(4-x)),color='red',label='5 seconds')
ax.plot(x,8-2*np.log(1+np.exp(4-3*x/5)),color='blue', label='10 seconds')
ax.plot(x,16-4*np.log(1+np.exp(4-3*x/8)),color='green', label='20 seconds')
ax.legend(frameon=False)
ax.set_xlim([0,20])
ax.set_ylim([0,20])
ax.set_xlabel(r'$t_{\mathrm{base}}$ (s)',fontsize=16)
ax.set_ylabel('Computer thinking time (s)',fontsize=16)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
fig.tight_layout()
fig.savefig(fig_direc + 'timedai_curves.pdf')
plt.show()
# Out:
# C:\Users\Bas\Anaconda3\lib\site-packages\matplotlib\backends\backend_pdf.py:1121: UserWarning: 'HelveticaNeueLTStd-Ex_0.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
#   warnings.warn(msg % os.path.basename(filename))
# C:\Users\Bas\Anaconda3\lib\site-packages\matplotlib\backends\backend_pdf.py:1121: UserWarning: 'helveticaneueltstd-roman_0.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
#   warnings.warn(msg % os.path.basename(filename))
