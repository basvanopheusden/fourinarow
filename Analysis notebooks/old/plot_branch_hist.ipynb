# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.loadtxt('C:/Users/Bas/Google Drive/Bas Games/Analysis/Tree/branch_hist.txt')

# %%
np.sum(x*range(len(x)))/np.sum(x)+1
# Out:
# 8.2780431707037216

# %%
plt.plot(np.cumsum(x)/np.sum(x),'.')
plt.axhline(0.5)
plt.show()

# %%
plt.plot(x)
plt.show()
